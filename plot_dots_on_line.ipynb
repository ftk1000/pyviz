# %% [markdown]
# <a href="https://colab.research.google.com/github/ftk1000/pyviz/blob/master/plot_dots_on_line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
fig = plt.figure()
ax = plt.axes()

t = np.linspace(0, 10, 100)
x = t*np.cos(t)/10
y = t*np.sin(t)/10
ax.plot(x, y, color='#FFDD44');

t = np.linspace(0, 10, 30)
x = t*np.cos(t)/10
y = t*np.sin(t)/10
plt.plot(x, y, 'o', color='black');

# %% [markdown]
# ##### The primary difference of plt.scatter from plt.plot is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.
#
# https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.02-Simple-Scatter-Plots.ipynb#scrollTo=yp63M16imqHu

# %%
N=10
rng = np.random.RandomState(0)
x = rng.randn(N)
y = rng.randn(N)
colors = rng.rand(N)
sizes = 1000 * rng.rand(N)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %%
fig = plt.figure()
ax = plt.axes()

t = np.linspace(0, 10, 100)
x = t*np.cos(t)/10
y = t*np.sin(t)/10
ax.plot(x, y, color='#FFDD44');

N=30
t = np.linspace(0, 10, N)
x = t*np.cos(t)/10
y = t*np.sin(t)/10
# plt.plot(x, y, 'o', color='black');
colors = rng.rand(N)
sizes = 1000 * rng.rand(N)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show co
