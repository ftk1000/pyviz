# %%
# use this to create inline image
# %matplotlib inline     

# use this to create interactive image
# %matplotlib notebook   

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

X = np.arange(0, 5)
Y = np.arange(0, 5)
X, Y = np.meshgrid(X, Y)
Z = np.array([[-122.        , -113.12765957, -103.69853575, -112.81437126,        -112.27692308],
       [-109.93548387, -112.79308511, -106.61994356, -112.84059457,        -112.27927928],
       [-109.29885057, -109.88036411,  -93.96936634, -112.45416667,        -113.53333333],
       [-118.4       , -113.        , -108.6       , -115.13461538,        -118.57142857],
       [          -111, -111.5       , -113.        , -112.92307692,        -111.83333333]])


fig = plt.figure(figsize=(10,7))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot', linewidth=0, antialiased=False)
ax.set_zlim( np.min(Z)-1, np.max(Z)+1)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
# use this to create inline image
# %matplotlib inline     

# use this to create interactive image
# %matplotlib notebook   
# 
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

X = np.arange(0, 5)
Y = np.arange(0, 5)
X, Y = np.meshgrid(X, Y)
Z = np.array([[-122.        , -113.12765957, -103.69853575, -112.81437126,        -112.27692308],
       [-109.93548387, -112.79308511, -106.61994356, -112.84059457,        -112.27927928],
       [-109.29885057, -109.88036411,  -93.96936634, -112.45416667,        -113.53333333],
       [-118.4       , -113.        , -108.6       , -115.13461538,        -118.57142857],
       [          -111, -111.5       , -113.        , -112.92307692,        -111.83333333]])


fig = plt.figure(figsize=(10,7))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot', linewidth=0, antialiased=False)
ax.set_zlim( np.min(Z)-1, np.max(Z)+1)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
